# %%
# 크롤링 데이터 불러오기
import pandas as pd
raw_total = pd.read_excel('./files/1_crawling_daegucafe_500.xlsx')
raw_total.head()
# Out:
#    Unnamed: 0                                            content        date  \
# 0           0                             누가 나도 좀 대구로 보내주라주! 🙏🏻🤎  2021-08-10
# 1           1                               요때는 좀 상콤했던 거 같은데ㅔ...  2021-08-10
# 2           2                                         머리 넘 길댜 그징  2021-08-10
# 3           3     언제와도 heal&cozy 🏡#대구카페 #대봉동카페 #한옥카페 #이이알티 #eert  2021-08-10
# 4           4  *컨텐츠활용 동의하지않습니다.삼덕동(혹은 동인동) 브루잉커피 맛집 검은구상의 새로운...  2021-08-11
#
#   like                    place  \
# 0  241                     썬빌로우
# 1  159                      NaN
# 2  392       Daegu, South Korea
# 3  135                     이이알티
# 4  868  대구 - Daegu, South Korea
#
#                                              tags
# 0                                              []
# 1                                              []
# 2                                              []
# 3  ['#대구카페', '#대봉동카페', '#한옥카페', '#이이알티', '#eert']
# 4                    ['#스탑바이검은구상', '#검은구상빨리다녀오면']

# %%
# 위치정보 가져오기
location_counts = raw_total['place'].value_counts()
location_counts
# Out:
# Daegu, South Korea    44
# Daegu                 14
# 경북대학교                  7
# 경대북문 커피장인              5
# 죽전네거리                  4
#                       ..
# Dining Slowlife        1
# 카이스샌드위치샵               1
# 와글라스                   1
# 충남 서산 개심사              1
# 오크커피                   1
# Name: place, Length: 198, dtype: int64

# %%
# 등록된 위치정보별 빈도수 데이터
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()
# Out:
#                     place
# Daegu, South Korea     44
# Daegu                  14
# 경북대학교                   7
# 경대북문 커피장인               5
# 죽전네거리                   4

# %%
location_counts_df.to_excel('./files/daegu_location_counts.xlsx')

# %%
locations = list(location_counts.index)
locations
# Out:
# ['Daegu, South Korea',
#  'Daegu',
#  '경북대학교',
#  '경대북문 커피장인',
#  '죽전네거리',
#  '팔공산',
#  'Nicethat',
#  'Busan, South Korea',
#  '대구 - Daegu, South Korea',
#  '인터즈',
#  'Gwangju, South Korea',
#  '대구 테크노폴리스',
#  '롤러커피 & Roller Coffee',
#  'Busan 釜山, South Korea',
#  '월든',
#  '대구 지묘동',
#  '경주 황리단길',
#  '슬루',
#  '동성로',
#  'The Dance 2017',
#  '성당못빌',
#  '모닝플라워',
#  'Nail Trend J 트렌드제이',
#  '𝐏𝐈𝐀𝐙𝐙𝐀 피아자',
#  '대구 동성로 어느거리',
#  '대구시수성구',
#  '호재담',
#  '로카커피',
#  '이이알티',
#  '유달동의 로망스',
#  '𝐁𝐞𝐫𝐥𝐢𝐧 𝐄𝐬𝐩𝐫𝐞𝐬𝐬𝐨 𝐁𝐚𝐫',
#  '하루',
#  '골목서재',
#  '흰여울문화마을',
#  '대릉원 천마총',
#  'One of',
#  'Cheongju',
#  '지산동 바우어카페',
#  '삼덕동',
#  'Gumi',
#  '육값어치',
#  '남구 (광주광역시)',
#  '대구신세계백화점',
#  '맛집추천',
#  '카페베버',
#  '카페올브',
#  '모어모어',
#  '경상북도 경산시 하양읍',
#  '카페담',
#  '가장 낭만적인 위로, Dayday.',
#  '불로동고분군',
#  '진천동',
#  '대구 근대골목단팥빵',
#  '고바슨커피',
#  '썬빌로우',
#  '카페스톤',
#  'Frankplank 프랭크프랭크',
#  '신천 수성교',
#  '한훤당고택',
#  '카페 라파르',
#  '동성로 어딘가',
#  '치우친취향',
#  'Ulsan, South Korea',
#  'Gyeongju, Korea',
#  'The Westin DAEGU',
#  '1972forpausing',
#  '동성로 미술관',
#  '그로잉, Growing',
#  '엠비언트',
#  '카페니어바이',
#  '칠성 꽃시장',
#  '수성못 (Suseong Lake)',
#  '풀베개',
#  'Mtl Hanmam',
#  '오가닉모가',
#  'little butler',
#  '12-12',
#  'D&department JEJU by Arario',
#  '수수밀소',
#  '비둘기는 멍청해 보여',
#  '미남장어 수성점',
#  '단하나케이크',
#  '모리베이커리 MORI Bakery',
#  '됴심',
#  '파라다이스호텔 부산',
#  '白金堂 백금당',
#  '블루닷',
#  '고유의색채',
#  '젬스톤',
#  '동구 (대구광역시)',
#  '수묵',
#  '오디너리하우스',
#  '포항 영일대해수욕장',
#  'Pohang',
#  'Coffitude',
#  '읍천리382',
#  '핀르 Finleu',
#  '두낫디스터브 세천',
#  '데프커피',
#  'Dryklutch, 드라이클러치',
#  'Cafe mnt',
#  '식당 마요네즈',
#  '대구 상인동',
#  '학선정',
#  '이쿠조',
#  'TOXIC Coffee Roasters',
#  '인오브x인프피스튜디오',
#  '카페우즈',
#  '비비당',
#  '강정보',
#  '카페패럿',
#  '전포카페거리 전리단길 전포사잇길',
#  '중구 동인동',
#  'IWLT',
#  '수성호텔 수성스퀘어',
#  '튜즈데이모닝플라워스튜디오',
#  'Merymery 메리메리',
#  '골목끝집',
#  '미완주택',
#  '단백질빵빵',
#  '나의 계절,봄',
#  '랑데자뷰 대구',
#  '해피치즈스마일',
#  '이호테우해변',
#  'Tribe Restaurant',
#  '카페 애하',
#  '대구 앞산',
#  'Haeundae, Busan',
#  'Lees cafe',
#  '대우 월드마크 웨스트엔드',
#  '더 플레이그라운드 로스터리카페',
#  '카페어썸',
#  '자연충만',
#  '군산빨간곱창',
#  'Jeju',
#  '대구 달서구 월성동',
#  'O.A.C Roasters',
#  '고삐식당',
#  '포도',
#  '모모드',
#  'South Korea',
#  '경상북도영주시',
#  '카페 모인모인',
#  '컬렉팅더모먼츠 삼덕점',
#  '뷰티셀럽',
#  '로이드밤 침산점',
#  '범물동',
#  'Gangneung',
#  '행복한 봄이네집',
#  '앞산카페거리',
#  '룰리커피',
#  '교동',
#  '경대병원역',
#  '넌테이블',
#  '커피필라소피대구',
#  'Gwangju',
#  '위시카페',
#  '카페코튼',
#  'Ltr Coffee',
#  '파더스베이글범어점',
#  '두낫헤지테이트 삼덕',
#  '두낫디스터브동대구점',
#  '오브닛 𝚘𝚏 𝚗𝚎𝚊𝚝',
#  '프롬오지',
#  '마르텐사이트',
#  'Double door',
#  'Laget om 라겟옴',
#  '플로리아나',
#  '대구북구',
#  '무니스',
#  '어썸브루커피',
#  '요거트월드',
#  '백록다방',
#  '아미꼬뜨',
#  'Seoul, Korea',
#  'Daejeon',
#  'Cafe.sandylake',
#  '카페슈츠',
#  '레드봉봉',
#  '대구광역시 서구 중리동',
#  '아눅앞산',
#  '대구 슈가파인',
#  '아르떼뮤지엄 Arte Museum',
#  '더무빙',
#  '커피팀버 월성점',
#  '계명대학교',
#  'Honeyday',
#  '달성하목정',
#  '𝚏𝚒,𝚜𝚑 𝚌𝚘𝚏𝚏𝚎𝚎 𝚋𝚊𝚛',
#  '사네',
#  'Suwon',
#  'Fancy Detail',
#  '슈드해브커피',
#  'Dining Slowlife',
#  '카이스샌드위치샵',
#  '와글라스',
#  '충남 서산 개심사',
#  '오크커피']

# %%
# 카카오 api 검색예시
import requests
url = 'http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": "KakaoAK 751f5590cde8e8767524436d35b711ca"
}
places = requests.get(url,headers = headers).json()['documents']
places
# Out:
# [{'address_name': '대구 북구 산격동 1370-1',
#   'category_group_code': 'SC4',
#   'category_group_name': '학교',
#   'category_name': '교육,학문 > 학교 > 대학교',
#   'distance': '',
#   'id': '18445477',
#   'phone': '053-950-5114',
#   'place_name': '경북대학교 대구캠퍼스',
#   'place_url': 'http://place.map.kakao.com/18445477',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.612177806453',
#   'y': '35.8906303894606'},
#  {'address_name': '경북 상주시 가장동 386',
#   'category_group_code': 'SC4',
#   'category_group_name': '학교',
#   'category_name': '교육,학문 > 학교 > 대학교',
#   'distance': '',
#   'id': '8187666',
#   'phone': '054-532-6006',
#   'place_name': '경북대학교 상주캠퍼스',
#   'place_url': 'http://place.map.kakao.com/8187666',
#   'road_address_name': '경북 상주시 경상대로 2559',
#   'x': '128.1454235824074',
#   'y': '36.37842642497381'},
#  {'address_name': '대구 북구 산격동',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교통,수송 > 도로시설 > 교차로',
#   'distance': '',
#   'id': '8179132',
#   'phone': '',
#   'place_name': '경북대학교북문교차로',
#   'place_url': 'http://place.map.kakao.com/8179132',
#   'road_address_name': '',
#   'x': '128.609230041745',
#   'y': '35.8925010432922'},
#  {'address_name': '대구 북구 대현동 25',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교통,수송 > 입출구',
#   'distance': '',
#   'id': '18092665',
#   'phone': '',
#   'place_name': '경북대학교 정문',
#   'place_url': 'http://place.map.kakao.com/18092665',
#   'road_address_name': '',
#   'x': '128.614496808498',
#   'y': '35.8855060008441'},
#  {'address_name': '대구 북구 산격동 1370-1',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교통,수송 > 입출구',
#   'distance': '',
#   'id': '25926005',
#   'phone': '',
#   'place_name': '경북대학교 북문',
#   'place_url': 'http://place.map.kakao.com/25926005',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.609406727498',
#   'y': '35.8922571702661'},
#  {'address_name': '대구 북구 복현동 573',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '부동산 > 주거시설 > 기숙사,기숙시설',
#   'distance': '',
#   'id': '443117484',
#   'phone': '',
#   'place_name': '경북대학교 생활관 누리관',
#   'place_url': 'http://place.map.kakao.com/443117484',
#   'road_address_name': '',
#   'x': '128.61356021837153',
#   'y': '35.89348464660513'},
#  {'address_name': '대구 북구 대현동 25',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교통,수송 > 입출구',
#   'distance': '',
#   'id': '1305598876',
#   'phone': '',
#   'place_name': '경북대학교 동문',
#   'place_url': 'http://place.map.kakao.com/1305598876',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.616442268997',
#   'y': '35.8883850963789'},
#  {'address_name': '대구 북구 대현동 526-2',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교통,수송 > 입출구',
#   'distance': '',
#   'id': '1359751560',
#   'phone': '',
#   'place_name': '경북대학교 서문',
#   'place_url': 'http://place.map.kakao.com/1359751560',
#   'road_address_name': '',
#   'x': '128.604018667428',
#   'y': '35.8884543708499'},
#  {'address_name': '대구 북구 복현동 573',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교육,학문 > 학교부속시설',
#   'distance': '',
#   'id': '16894941',
#   'phone': '053-950-4000',
#   'place_name': '경북대학교 대구캠퍼스 정보화본부',
#   'place_url': 'http://place.map.kakao.com/16894941',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.61355086705677',
#   'y': '35.89138692469232'},
#  {'address_name': '대구 북구 복현동 573',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교육,학문 > 학교부속시설',
#   'distance': '',
#   'id': '17561296',
#   'phone': '',
#   'place_name': '경북대학교 생활관 첨성관',
#   'place_url': 'http://place.map.kakao.com/17561296',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.614944010435',
#   'y': '35.8913862184712'},
#  {'address_name': '대구 북구 산격동 1370-1',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교육,학문 > 학교부속시설',
#   'distance': '',
#   'id': '17556017',
#   'phone': '053-950-7122',
#   'place_name': '경북대학교 글로벌플라자',
#   'place_url': 'http://place.map.kakao.com/17556017',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.611259363988',
#   'y': '35.8918682645968'},
#  {'address_name': '대구 북구 대현동 25',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교육,학문 > 학교 > 대학원',
#   'distance': '',
#   'id': '17567406',
#   'phone': '053-950-5456',
#   'place_name': '경북대학교 법학전문대학원',
#   'place_url': 'http://place.map.kakao.com/17567406',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.61484284861612',
#   'y': '35.88809572383076'},
#  {'address_name': '대구 중구 삼덕동2가 50',
#   'category_group_code': 'HP8',
#   'category_group_name': '병원',
#   'category_name': '의료,건강 > 병원 > 대학병원',
#   'distance': '',
#   'id': '8645867',
#   'phone': '1666-5114',
#   'place_name': '경북대학교병원',
#   'place_url': 'http://place.map.kakao.com/8645867',
#   'road_address_name': '대구 중구 동덕로 130',
#   'x': '128.6042556975969',
#   'y': '35.86649581373473'},
#  {'address_name': '대구 북구 복현동 573',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교육,학문 > 학교부속시설',
#   'distance': '',
#   'id': '22028576',
#   'phone': '',
#   'place_name': '경북대학교 중앙도서관',
#   'place_url': 'http://place.map.kakao.com/22028576',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.612642907305',
#   'y': '35.8919398048101'},
#  {'address_name': '대구 북구 복현동 573',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '교육,학문 > 학교부속시설',
#   'distance': '',
#   'id': '13106950',
#   'phone': '053-950-8553',
#   'place_name': '경북대학교 약학대학',
#   'place_url': 'http://place.map.kakao.com/13106950',
#   'road_address_name': '대구 북구 대학로 80',
#   'x': '128.612390201384',
#   'y': '35.8925848083558'}]

# %%
# 카카오 로컬 api를 활용한 장소 검색 함수 만들기
def find_places(search):
    # 1. 접속 url 만들기
    url = 'http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(search)
    # 2. headers 입력하기
    headers = {
        "Authorization": "KakaoAK 751f5590cde8e8767524436d35b711ca"
    }
    # 3. api 요청, 정보 받기
    places = requests.get(url,headers = headers).json()['documents']
    # 4. 필요한 정보 선택하기
    place = places[0]
    name = place['place_name']
    x=place['x']
    y=place['y']
    data = [name,x,y,search]
    
    return data

# %%
# 대구 시청 검색
data = find_places('대구시청')
data
# Out:
# ['대구광역시청', '128.601805491082', '35.8713802646523', '대구시청']

# %%
# 반복 작업 실행시 진행바 표시하기위한 라이브러리 tqdm 설치하기
from tqdm.notebook import tqdm

# %%
# 인스타그램 위치명 위치정보 검색하기
# 검색시 시간이 많이 걸려, 현재 작업 진행현황을 볼 수 있게 , tqdm_notebook 추가
import time
locations_inform = []
for locations in tqdm(locations):
    try:
        data = find_places(locations)
        locations_inform.append(data)
        time.sleep(0.5)
    except:
        pass

locations_inform
# Out:
#   0%|          | 0/198 [00:00<?, ?it/s]
# [['대구역', '128.596277196438', '35.8759487657024', 'Daegu'],
#  ['경북대학교 대구캠퍼스', '128.612177806453', '35.8906303894606', '경북대학교'],
#  ['커피장인 경대북문점', '128.611368143536', '35.8950496222844', '경대북문 커피장인'],
#  ['죽전네거리', '128.537246615899', '35.8501745400839', '죽전네거리'],
#  ['팔공산', '128.69533079909814', '36.0165363755889', '팔공산'],
#  ['대구테크노폴리스지구', '128.457024877037', '35.6928738720481', '대구 테크노폴리스'],
#  ['롤러커피', '128.5893607410422', '35.86449504411073', '롤러커피 & Roller Coffee'],
#  ['월든', '128.563152306098', '35.7155530761797', '월든'],
#  ['신숭겸장군유적지', '128.640979002345', '35.9427148480857', '대구 지묘동'],
#  ['황리단길', '129.209645417434', '35.8393348165945', '경주 황리단길'],
#  ['슬루', '128.624803068934', '35.2635566973001', '슬루'],
#  ['서면아이파크1단지아파트', '129.06948112758545', '35.15570907878796', '동성로'],
#  ['더댄스2017', '128.58624847286558', '35.86897882907464', 'The Dance 2017'],
#  ['성당못 빌', '128.561504357618', '35.842018069239', '성당못빌'],
#  ['모닝 플라워', '128.713444778571', '35.8713100712466', '모닝플라워'],
#  ['네일트렌드제이', '128.464624991504', '35.8575702256326', 'Nail Trend J 트렌드제이'],
#  ['피아자', '128.555899712991', '35.8672229660451', '𝐏𝐈𝐀𝐙𝐙𝐀 피아자'],
#  ['수성못', '128.618706461918', '35.8274482551946', '대구시수성구'],
#  ['로카커피', '128.572012590465', '35.6904752499838', '로카커피'],
#  ['EERT', '127.04099944900322', '37.54743405615237', '이이알티'],
#  ['유달동의로망스', '126.381545427367', '34.7862423643144', '유달동의 로망스'],
#  ['하루', '127.113167611141', '35.6038356588423', '하루'],
#  ['골목서재', '128.60431010043226', '35.89389696006169', '골목서재'],
#  ['흰여울문화마을', '129.04528136992104', '35.077914827298564', '흰여울문화마을'],
#  ['천마총', '129.210559431045', '35.8384565998858', '대릉원 천마총'],
#  ['원오브디(one of d)', '126.932936779199', '37.5568078260595', 'One of'],
#  ['청주역', '127.392335249207', '36.6471521939553', 'Cheongju'],
#  ['바우어', '128.64350062985358', '35.826687256510766', '지산동 바우어카페'],
#  ['야시골목', '128.597549543958', '35.8667474038363', '삼덕동'],
#  ['구미역', '128.331016235023', '36.1282722213369', 'Gumi'],
#  ['육값어치', '127.132240280276', '37.4320256059927', '육값어치'],
#  ['남구다목적체육관', '126.90861255250248', '35.11406896569779', '남구 (광주광역시)'],
#  ['신세계백화점 대구점', '128.6289648557988', '35.8777969311124', '대구신세계백화점'],
#  ['모이핀', '127.77908440127192', '34.687850799489055', '맛집추천'],
#  ['카페베버', '128.610444033125', '35.864729666769', '카페베버'],
#  ['카페올브', '128.6125093738', '35.8350831787654', '카페올브'],
#  ['모어모어', '128.640025272156', '35.8626028209189', '모어모어'],
#  ['하양유원지', '128.8025501200635', '35.89900527224052', '경상북도 경산시 하양읍'],
#  ['카페담', '128.50005927536242', '35.714896304649294', '카페담'],
#  ['가장낭만적인위로 데이데이',
#   '128.64020058201',
#   '35.8564979201417',
#   '가장 낭만적인 위로, Dayday.'],
#  ['불로동고분군', '128.646852356957', '35.9151608131731', '불로동고분군'],
#  ['대구수목원', '128.522017358965', '35.7997197025815', '진천동'],
#  ['근대골목단팥빵 동성로점', '128.593194434991', '35.8670900127039', '대구 근대골목단팥빵'],
#  ['고바슨커피 동성로아비뇽점', '128.59658724871113', '35.86833629853508', '고바슨커피'],
#  ['썬빌로우', '128.607610248615', '35.8638133190782', '썬빌로우'],
#  ['카페 스톤', '128.63071974912617', '36.02987423578147', '카페스톤'],
#  ['프랭크프랭크', '128.629614988326', '35.8765625643188', 'Frankplank 프랭크프랭크'],
#  ['수성교', '128.608841257129', '35.861456570815', '신천 수성교'],
#  ['한훤당고택 바이소가', '128.427102233739', '35.6713947251088', '한훤당고택'],
#  ['라파르', '126.39707933088397', '35.81288280009246', '카페 라파르'],
#  ['치우친취향', '128.567901421284', '35.949603333967', '치우친취향'],
#  ['더웨스틴대구', '128.579377531658', '35.8344887373155', 'The Westin DAEGU'],
#  ['대구가톨릭대학교 CU갤러리', '128.587438587421', '35.868254805989', '동성로 미술관'],
#  ['그로잉살롱 본점', '127.022587563336', '37.5193430993599', '그로잉, Growing'],
#  ['엠비언트', '128.48284924971662', '36.06202739321963', '엠비언트'],
#  ['카페니어바이', '129.477190094984', '36.0138462656036', '카페니어바이'],
#  ['칠성꽃도매시장', '128.601045638655', '35.8754347201061', '칠성 꽃시장'],
#  ['풀베개', '126.303224677035', '33.285512856952', '풀베개'],
#  ['오가닉모가', '128.605107909027', '35.8593473791069', '오가닉모가'],
#  ['리틀버틀러', '126.985962346853', '37.5776011992524', 'little butler'],
#  ['보경사12폭포', '129.31106827105', '36.2523654260037', '12-12'],
#  ['D', '126.734256737675', '37.50793875955', 'D&department JEJU by Arario'],
#  ['수수밀소', '128.715042760351', '35.9068536906751', '수수밀소'],
#  ['비둘기는멍청해보여', '128.751833444696', '35.8363396723106', '비둘기는 멍청해 보여'],
#  ['미남장어 수성점', '128.6171565679764', '35.8347188374113', '미남장어 수성점'],
#  ['단하나케이크 홍대점', '126.924366040544', '37.5534148963118', '단하나케이크'],
#  ['됴심', '128.077080568531', '36.760676748803', '됴심'],
#  ['파라다이스호텔 부산', '129.1652676273964', '35.16022162668545', '파라다이스호텔 부산'],
#  ['블루닷카페', '128.4420401370711', '36.04038080537632', '블루닷'],
#  ['고유의색채', '128.573080420586', '35.8327942753474', '고유의색채'],
#  ['젬스톤 송정점', '129.19753088905364', '35.17140384221137', '젬스톤'],
#  ['동구시장', '128.63964963846', '35.8744597017712', '동구 (대구광역시)'],
#  ['수묵', '128.609078504223', '35.866182585376', '수묵'],
#  ['카페오디너리하우스', '128.595968341351', '35.8671757414424', '오디너리하우스'],
#  ['영일대해수욕장', '129.378187000619', '36.0550695749354', '포항 영일대해수욕장'],
#  ['포항역', '129.34192815800867', '36.07160517955013', 'Pohang'],
#  ['커피튜드', '128.625439836977', '35.8632949090944', 'Coffitude'],
#  ['읍천리382 본점', '128.576962184054', '35.8379232046887', '읍천리382'],
#  ['두낫디스터브 세천', '128.470413533051', '35.8734536498686', '두낫디스터브 세천'],
#  ['데프커피', '128.624808600119', '35.8358366529819', '데프커피'],
#  ['MNT', '128.52594809422726', '35.823044168669455', 'Cafe mnt'],
#  ['식당마요네즈', '126.478663136608', '33.4888876246804', '식당 마요네즈'],
#  ['낙동서원', '128.545528613694', '35.8197282046761', '대구 상인동'],
#  ['학선정', '128.48204516030535', '36.01736090750451', '학선정'],
#  ['이쿠조', '128.607323585825', '35.8632683599111', '이쿠조'],
#  ['카페우즈', '128.65688759351337', '36.04978322455591', '카페우즈'],
#  ['비비당', '128.601907639799', '35.9195934150828', '비비당'],
#  ['강정보디아크광장', '128.465058159856', '35.8411637749681', '강정보'],
#  ['패럿', '128.759641450778', '35.8403752426019', '카페패럿'],
#  ['동인동찜갈비골목', '128.60504217131', '35.8711279887378', '중구 동인동'],
#  ['IWLT', '128.624526934995', '35.8337462036616', 'IWLT'],
#  ['호텔수성 수성스퀘어', '128.62017625871852', '35.82523145387428', '수성호텔 수성스퀘어'],
#  ['튜즈데이모닝 플라워스튜디오', '128.566805620756', '35.858213000355505', '튜즈데이모닝플라워스튜디오'],
#  ['골목끝집', '129.079088033335', '35.2058704645238', '골목끝집'],
#  ['미완주택', '128.58959940495754', '35.86691055712817', '미완주택'],
#  ['단백질빵빵', '128.719254029782', '35.8780251329959', '단백질빵빵'],
#  ['나의계절봄', '128.546839867537', '35.9100137973743', '나의 계절,봄'],
#  ['랑데자뷰 대구동성로점', '128.597313930044', '35.8682464348226', '랑데자뷰 대구'],
#  ['해피치즈스마일', '128.60810369837478', '35.864620444827125', '해피치즈스마일'],
#  ['이호테우해수욕장', '126.452690819027', '33.4973768007144', '이호테우해변'],
#  ['애하', '128.5934503918138', '35.88959714493148', '카페 애하'],
#  ['대구앞산공원', '128.587651981127', '35.8272137479641', '대구 앞산'],
#  ['해운대역 부산2호선', '129.158897240251', '35.1636479638612', 'Haeundae, Busan'],
#  ['리스카페', '127.112136888517', '37.3860826752748', 'Lees cafe'],
#  ['대우월드마크웨스트엔드아파트', '128.5360150575584', '35.84830147436636', '대우 월드마크 웨스트엔드'],
#  ['더플레이그라운드로스터리카페', '128.672112653574', '35.8474827401', '더 플레이그라운드 로스터리카페'],
#  ['카페어썸', '127.3487205269593', '36.36215594973519', '카페어썸'],
#  ['자연충만', '128.533418223539', '35.7828276046483', '자연충만'],
#  ['군산빨간곱창', '128.528954409846', '35.843283792855', '군산빨간곱창'],
#  ['Jeju in aA', '126.83650369902168', '33.53833652360498', 'Jeju'],
#  ['엘리바덴 신월성점', '128.525885615368', '35.8249824533011', '대구 달서구 월성동'],
#  ['오에이씨로스터스', '128.569493676523', '35.83722437912', 'O.A.C Roasters'],
#  ['고삐식당', '128.59174166279', '35.8675201958936', '고삐식당'],
#  ['포도몰', '126.930347235595', '37.4838899689737', '포도'],
#  ['살롱드모모', '127.46093182873848', '36.65023618236355', '모모드'],
#  ['PPE', '127.059936935972', '37.5162738482712', 'South Korea'],
#  ['소수서원', '128.580202883743', '36.9256206705394', '경상북도영주시'],
#  ['모인모인', '129.429366235685', '35.5132397364629', '카페 모인모인'],
#  ['컬렉팅더모먼츠', '128.60565672273', '35.8646027170146', '컬렉팅더모먼츠 삼덕점'],
#  ['뷰티셀럽', '128.636760431546', '35.922785431482', '뷰티셀럽'],
#  ['로이드밤 침산점', '128.589678702119', '35.8914890683159', '로이드밤 침산점'],
#  ['용지봉', '128.649752551383', '35.80332236114577', '범물동'],
#  ['강릉역', '128.899627553491', '37.7645235587621', 'Gangneung'],
#  ['앞산카페거리', '128.578944420386', '35.835640692434', '앞산카페거리'],
#  ['룰리커피', '128.67970833536202', '35.85675036609653', '룰리커피'],
#  ['강릉향교', '128.89525828109', '37.7635273361304', '교동'],
#  ['경대병원역 대구2호선', '128.6029028791839', '35.863145404232455', '경대병원역'],
#  ['넌테이블', '128.59084140599873', '35.871443086471615', '넌테이블'],
#  ['커피필라소피 대구점', '128.52859215075836', '35.799471360688365', '커피필라소피대구'],
#  ['광주경찰서', '127.239583690907', '37.408267273136', 'Gwangju'],
#  ['위시카페', '128.59368295627257', '35.87572729485913', '위시카페'],
#  ['카페코튼 베이커리카페', '128.607779579495', '35.869180955838', '카페코튼'],
#  ['엘티알커피', '128.592547441178', '35.8679528772372', 'Ltr Coffee'],
#  ['파더스베이글 대구범어점', '128.62302658634889', '35.861128760502815', '파더스베이글범어점'],
#  ['두낫헤지테이트 삼덕', '128.608740961248', '35.864381218902', '두낫헤지테이트 삼덕'],
#  ['두낫디스터브 동대구점', '128.62917646216076', '35.87623509327027', '두낫디스터브동대구점'],
#  ['오브닛', '128.597444699104', '35.8718925209502', '오브닛 𝚘𝚏 𝚗𝚎𝚊𝚝'],
#  ['프롬오지', '128.605607560581', '35.8561290270755', '프롬오지'],
#  ['마르텐사이트', '128.439494706236', '35.9000736147977', '마르텐사이트'],
#  ['플로리아나', '128.467577358634', '35.8572710539279', '플로리아나'],
#  ['하중도', '128.559586718274', '35.900498621758', '대구북구'],
#  ['무니스', '128.518616375301', '35.8111930599368', '무니스'],
#  ['어썸브루커피', '128.61075760558225', '35.894542363742005', '어썸브루커피'],
#  ['요거트월드', '126.828146965472', '37.3130096810059', '요거트월드'],
#  ['백록다방', '129.2074677741824', '35.840537205047575', '백록다방'],
#  ['아미꼬뜨', '128.899836978838', '35.6433831031038', '아미꼬뜨'],
#  ['페이스뮤직', '126.915848984951', '37.5512791744838', 'Seoul, Korea'],
#  ['Daejeon제일공인중개사사무소', '127.3701816330705', '36.34671554341633', 'Daejeon'],
#  ['슈츠', '128.586972296627', '36.0124929188604', '카페슈츠'],
#  ['퀸스로드패션타운', '128.544343581599', '35.8617984908021', '대구광역시 서구 중리동'],
#  ['아눅앞산', '128.575169858919', '35.8322406303442', '아눅앞산'],
#  ['슈가파인', '128.588247858495', '35.7844659986524', '대구 슈가파인'],
#  ['아르떼뮤지엄 제주',
#   '126.34501060259869',
#   '33.39670048068425',
#   '아르떼뮤지엄 Arte Museum'],
#  ['더무빙', '129.27009253505074', '35.32264983199726', '더무빙'],
#  ['계명대학교 성서캠퍼스', '128.4845369032987', '35.85587403440843', '계명대학교'],
#  ['하목정', '128.39754538874', '35.8817781037634', '달성하목정'],
#  ['사네', '127.06856338188518', '36.83127487910888', '사네'],
#  ['수원박물관', '127.035410325887', '37.2977394743763', 'Suwon'],
#  ['카이스샌드위치샵', '128.597509282411', '35.862094434879', '카이스샌드위치샵'],
#  ['와글라스', '128.622315234844', '35.8268661093549', '와글라스'],
#  ['개심사', '126.590367168411', '36.7466679274501', '충남 서산 개심사'],
#  ['오크커피', '128.60793610628', '35.2563235325265', '오크커피']]

# %%
# 위치 정보 저장하기
locations_inform_df = pd.DataFrame(locations_inform)
locations_inform_df.columns = ['name_official','경도','위도','인스타 위치명']
locations_inform_df.to_excel('./files/daegu_locations.xlsx',index = False)

# %%
# 인스타 게시량 및 위치정보 데이터 불러오기
locations_counts_df=pd.read_excel('./files/daegu_location_counts.xlsx',index_col = 0)
locations_inform_df=pd.read_excel('./files/daegu_locations.xlsx')

# %%
# 위치 데이터 병합하기
location_data = pd.merge(locations_inform_df,locations_counts_df,how='inner',left_on='name_official',right_index=True)
location_data.head()
# Out:
#    name_official          경도         위도 인스타 위치명  place
# 3          죽전네거리  128.537247  35.850175   죽전네거리      4
# 4            팔공산  128.695331  36.016536     팔공산      4
# 7             월든  128.563152  35.715553      월든      3
# 10            슬루  128.624803  35.263557      슬루      2
# 18          로카커피  128.572013  35.690475    로카커피      2

# %%
location_data['name_official'].value_counts()
# Out:
# 육값어치          1
# 사네            1
# 룰리커피          1
# 카페어썸          1
# 파라다이스호텔 부산    1
#              ..
# 수수밀소          1
# 넌테이블          1
# 흰여울문화마을       1
# 뷰티셀럽          1
# 오크커피          1
# Name: name_official, Length: 62, dtype: int64

# %%
location_data = location_data.pivot_table(index=['name_official','경도','위도'],values='place',aggfunc='sum')
location_data
# Out:
#                                     place
# name_official 경도         위도
# IWLT          128.624527 35.833746      1
# 고삐식당          128.591742 35.867520      1
# 고유의색채         128.573080 35.832794      1
# 골목끝집          129.079088 35.205870      1
# 골목서재          128.604310 35.893897      1
# ...                                   ...
# 플로리아나         128.467577 35.857271      1
# 하루            127.113168 35.603836      1
# 학선정           128.482045 36.017361      1
# 해피치즈스마일       128.608104 35.864620      1
# 흰여울문화마을       129.045281 35.077915      1
#
# [62 rows x 1 columns]

# %%
# 병합한 데이터 저장하기
location_data.to_excel('./files/daegu_location_inform.xlsx')

# %%
# 데이터 불러오기
location_data = pd.read_excel('./files/daegu_location_inform.xlsx')
location_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name_official  62 non-null     object
#  1   경도             62 non-null     float64
#  2   위도             62 non-null     float64
#  3   place          62 non-null     int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 2.1+ KB

# %%
# 지도 표시하기
import folium

daegu = ['128.601805491082', '35.8713802646523']
map_daegu = folium.Map(location=daegu,zoom_start = 3)

for i in range(len(location_data)):
    name = location_data['name_official'][i]
    count = location_data['place'][i]
    size = int(count)* 8
    long = float(location_data['위도'][i])
    lat = float(location_data['경도'][i])
    folium.CircleMarker((long,lat),radius=size,color='red',popup=name).add_to(map_daegu)
    
map_daegu
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bf8beff57860440eb1db2a0ebc8fb95f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bf8beff57860440eb1db2a0ebc8fb95f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bf8beff57860440eb1db2a0ebc8fb95f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bf8beff57860440eb1db2a0ebc8fb95f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B128.601805491082%2C%2035.8713802646523%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# 지도 저장하기
map_daegu.save('./files/daegu_cafe.html')

# %%
from folium.plugins import MarkerCluster

locations =[]
names =[]

for i in range(len(location_data)):
    data = location_data.iloc[i]
    locations.append((float(data['위도']),float(data['경도'])))
    names.append(data['name_official'])
    
daegu = ['128.601805491082', '35.8713802646523']
map_daegu2 = folium.Map(location=daegu,zoom_start = 3)

marker_cluster = MarkerCluster(
    locations= locations,popups=names,name='daegu',overLay=True,control=True)

marker_cluster.add_to(map_daegu2)
folium.LayerControl().add_to(map_daegu2)

map_daegu2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_351eaa1b50f642eda31ab00b1cc2da3c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_351eaa1b50f642eda31ab00b1cc2da3c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...
