# %%
import httplib2
import os
import sys
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

DEVELOPER_KEY = "AIzaSyDjrKEd8dVC9ykDsuzHtw4DTx1tIUddT9c"
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)
search_response = youtube.search().list(q = "리그오브레전드",order = "relevance",part = "snippet",maxResults = 30).execute()

# %%
del search_response['items'][0]

# %%
search_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'arSpFvLGNESmLub14w9jO45jGdk',
#  'nextPageToken': 'CB4QAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 30},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '0hm8hmeWlNfjJIHHhswB5RxhoyY',
#    'id': {'kind': 'youtube#video', 'videoId': 'q3lhNGHNu-c'},
#    'snippet': {'publishedAt': '2021-09-14T00:15:03Z',
#     'channelId': 'UCooLkG0FfrkPBQsSuC95L6w',
#     'title': '추석 이벤트! 보름달처럼 크고 달달하게! (Feat. R9M)｜리그 오브 레전드',
#     'description': '보름달처럼 크고 달달한 추석 이벤트가 돌아왔습니다. https://riot.com/LoL_KTD2021 애니메이터 R9M님께서 만드신 아기자기하고 우당탕탕 추석맞이 대소동을 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q3lhNGHNu-c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/q3lhNGHNu-c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/q3lhNGHNu-c/hqdefault.jpg',
#       'width': 480,
# ...

# %%
channel_id = search_response['items'][0]['snippet']['channelId']
channel_id
# Out:
# 'UCUj6rrhMTR9pipbAWBAMvUQ'

# %%
import pandas as pd
titles = []
views = []
likes =[]

# %%
for i in search_response['items']:
    titles.append(i['snippet']['title'])
    views.append(i['statistics']['viewCount'])
    likes.append(i['statistics']['likeCount'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d48c62b0499f> in <module>
#       1 for i in search_response['items']:
#       2     titles.append(i['snippet']['title'])
# ----> 3     views.append(i['statistics']['viewCount'])
#       4     likes.append(i['statistics']['likeCount'])
#
# KeyError: 'statistics'

# %%
videos_df = pd.DataFrame([dates,titles,ids]).T
videos_df.columns = ['Titles','Views','Likes']
videos_df
# Out:
#                     Date                             Titles          Ids
# 0   2021-08-26T10:00:07Z                   침착맨의 눈으로 보는 리니지W  Ii0RtCSo4E8
# 1   2021-08-26T10:00:07Z                        침착맨 삼국지 완전판  hnanNlDbsE4
# 2   2020-10-04T10:00:13Z           깊어가는 가을, 영시 한 편.. 어떠신가요?  gfEt-8m2GM8
# 3   2021-08-26T08:04:07Z              드래곤볼(Dragon Ball) 설명회  T3chPJuPPic
# 4   2021-04-20T10:30:08Z                  유사과학 월드컵 (이과답답주의)  Z7_WWJEj-j8
# 5   2021-04-12T11:45:01Z                     가장 아름다운 로고 월드컵  qbLpfBgZ2zg
# 6   2021-03-12T10:00:16Z                    어느 것이 더 검색 됐을까?  gUckM84W89Q
# 7   2021-08-24T10:00:17Z                     눈이 나빠질 거 같은 라면  e9ogQq2qcr0
# 8   2021-08-25T10:00:29Z                      이것은 마술인가 마법인가  CGJ2uB5TYqQ
# 9   2021-08-14T10:42:34Z                 음모론 &amp; 미스터리 월드컵  qRUxCTEtKMI
# 10  2021-07-13T10:00:18Z                      솔로몬의 72악마 설명회  nlTn_odOjHY
# 11  2021-03-09T10:00:32Z                  신개념 사업 구상: 가루 삼겹살  gwHQLBUStO4
# ...

# %%
import re
ids =[]
category_id =[]
views =[]
likes = []
dislikes = []
comments = []
title = []

# %%
for u in range(len(videos_df)):
    request = youtube.videos().list(
        part = 'snippet,contentDetails,statistics',
        id = videos_df['Ids'][u]
    )
    response = request.execute()
    title.append(response['items'][u]['snippet']['title'])
    category_id.append(response['items'][u]['snippet']['categoryId'])
    views.append(response['items'][u]['statistics']['viewCount'])
    likes.append(response['items'][u]['statistics']['likeCount'])
    dislikes.append(response['items'][u]['statistics']['dislikeCount'])
    comments.append(response['items'][u]['statistics']['commentCount'])
#     if response["items"] == [ ]:
#         ids.append('-')
#         category_id.append('-')
#         views.append('-')
#         likes.append('-')
#         dislikes.append('-')
#         comments.append('-')
#     else:
#         title.append(response['items'][0]['snippet']['title'])
#         category_id.append(response['items'][0]['snippet']['categoryId'])
#         views.append(response['items'][0]['statistics']['viewCount'])
#         likes.append(response['items'][0]['statistics']['likeCount'])
#         dislikes.append(response['items'][0]['statistics']['dislikeCount'])
#         comments.append(response['items'][0]['statistics']['commentCount'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dccdc3411417> in <module>
# ----> 1 for u in range(len(videos_df)):
#       2     request = youtube.videos().list(
#       3         part = 'snippet,contentDetails,statistics',
#       4         id = videos_df['Ids'][u]
#       5     )
#
# NameError: name 'videos_df' is not defined

# %%
playlists = youtube.playlists().list(
    channelId = channel_id,
    part = "snippet",
    maxResults = 20
).execute()

# %%
playlists
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'mHknj4htduP_06t80BfFC5pAJB0',
#  'nextPageToken': 'CBQQAA',
#  'pageInfo': {'totalResults': 182, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'FHtHCuO8vqFLHaDaYhr3SRb5lbE',
#    'id': 'PLif_jr7pPZADR0tmPGmDymr6XDuBvAuWD',
#    'snippet': {'publishedAt': '2021-07-17T08:38:10Z',
#     'channelId': 'UCUj6rrhMTR9pipbAWBAMvUQ',
#     'title': '침착맨의 뿌리를 찾아서',
#     'description': '침착맨의 일생 경험하기',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sJNC99aCHkQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sJNC99aCHkQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sJNC99aCHkQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/sJNC99aCHkQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
# ...

# %%
import pandas as pd
playlist_titles = []
playlist_ids = []

# %%
for i in playlists['items']:
    playlist_titles.append(i['snippet']['title'])
    playlist_ids.append(i['id'])

# %%
playlist_titles
# Out:
# ['침착맨의 뿌리를 찾아서',
#  '침착맨 삼국지 인물전',
#  '(2021 설특선) 침착맨 월드컵 베스트',
#  '쇼핑맨',
#  '2020 AMD 자낳대 시즌2 참가 영상',
#  '(2020 추석특선) 침착맨 클래식',
#  '설명맨',
#  '포켓몬스터 소드',
#  '2020 배도라지 25시간 MT',
#  '2020 AMD 자낳대 시즌1 참가 영상',
#  'GALAX배 배도라지 전장 으깨기 리그 시즌1',
#  '침착맨 삼국지',
#  '포켓몬스터 레츠고! 피카츄',
#  '배도라지 전장 으깨기 시범리그',
#  '침펄놈의 대모험 WOW Classic (풀버전)',
#  '침착맨 풀버전 영상 (정주행용)',
#  '화가 이말년: 증명그림 그려드립니다',
#  '月刊 침착맨',
#  '모여봐요 동물의 숲 (풀버전)',
#  '모여봐요 동물의 숲']

# %%
playlist_ids
# Out:
# ['PLif_jr7pPZADR0tmPGmDymr6XDuBvAuWD',
#  'PLif_jr7pPZACIf_-P3h9zwIa_ygaCPMqO',
#  'PLif_jr7pPZACS8gzTwX20TyZaD-vEbfr4',
#  'PLif_jr7pPZACNczCPv-JNMCfCgv5t6m8N',
#  'PLif_jr7pPZAB1Png8K3ZG6TP9zgBWoz8S',
#  'PLif_jr7pPZADFbzhQOj-jHBRlJZ6gadJC',
#  'PLif_jr7pPZAB9KbXMwk5HgFtIBht-2HPq',
#  'PLif_jr7pPZADuRk12Dt-w_bWx2rodCmO5',
#  'PLif_jr7pPZACapOHnAWzpdpwFfManyk_c',
#  'PLif_jr7pPZABXwLCXYjKdun6Ne5wWXbRX',
#  'PLif_jr7pPZAAXwHMDbDXsGW7JY1blR67R',
#  'PLif_jr7pPZADzkIUTkp1MpzrjA_FvLy_9',
#  'PLif_jr7pPZACenVj0HmYIOSd7flh3r1hY',
#  'PLif_jr7pPZACBTkT6e2oEbweC7CmtDoi4',
#  'PLif_jr7pPZAA4nIROK4NrXwa--5tOJ_Em',
#  'PLif_jr7pPZACUS3QgLjDqZhz9Xvug-kBp',
#  'PLif_jr7pPZAAVEm3R5ldUt2J6iGcppUsR',
#  'PLif_jr7pPZAAnliJmCN528aomMoAvembU',
#  'PLif_jr7pPZAB73OFYpKclleEH4wcQQurX',
#  'PLif_jr7pPZACN9xo4QMTWEIVEgi9GOHre']

# %%
playlist_df = pd.DataFrame([playlist_titles,playlist_ids]).T
playlist_df.columns = ['playlist','playlist_id']

# %%
playlist_df
# Out:
#                       playlist                         playlist_id
# 0                 침착맨의 뿌리를 찾아서  PLif_jr7pPZADR0tmPGmDymr6XDuBvAuWD
# 1                  침착맨 삼국지 인물전  PLif_jr7pPZACIf_-P3h9zwIa_ygaCPMqO
# 2       (2021 설특선) 침착맨 월드컵 베스트  PLif_jr7pPZACS8gzTwX20TyZaD-vEbfr4
# 3                          쇼핑맨  PLif_jr7pPZACNczCPv-JNMCfCgv5t6m8N
# 4       2020 AMD 자낳대 시즌2 참가 영상  PLif_jr7pPZAB1Png8K3ZG6TP9zgBWoz8S
# 5          (2020 추석특선) 침착맨 클래식  PLif_jr7pPZADFbzhQOj-jHBRlJZ6gadJC
# 6                          설명맨  PLif_jr7pPZAB9KbXMwk5HgFtIBht-2HPq
# 7                     포켓몬스터 소드  PLif_jr7pPZADuRk12Dt-w_bWx2rodCmO5
# 8            2020 배도라지 25시간 MT  PLif_jr7pPZACapOHnAWzpdpwFfManyk_c
# 9       2020 AMD 자낳대 시즌1 참가 영상  PLif_jr7pPZABXwLCXYjKdun6Ne5wWXbRX
# 10   GALAX배 배도라지 전장 으깨기 리그 시즌1  PLif_jr7pPZAAXwHMDbDXsGW7JY1blR67R
# 11                     침착맨 삼국지  PLif_jr7pPZADzkIUTkp1MpzrjA_FvLy_9
# 12              포켓몬스터 레츠고! 피카츄  PLif_jr7pPZACenVj0HmYIOSd7flh3r1hY
# ...

# %%
video_ids =[]
video_titles = []
video_dates =[]

for playlist_id in playlist_df['playlist_id']:
    playlist_videos = youtube.playlistItems().list(
        playlistId = playlist_id,
        part = 'snippet',
        maxResults = 50
    )
    while playlist_videos:
        playlistitems_list_response = playlist_videos.execute()
        
        for playlist_item in playlistitems_list_response['items']:
            title = playlist_item['snippet']['title']
            video_id = playlist_item['snippet']['resourceId']['videoId']
            video_ids.append(video_id)
            video_titles.append(title)
        
        playlist_videos = youtube.playlistItems().list_next(
            playlist_videos,playlistitems_list_response
        )

# %%
video_df = pd.DataFrame()
video_df['Title'] = video_titles
video_df['Video Id'] = video_ids
video_df
# Out:
#                                                Title     Video Id
# 0                             침착맨의 뿌리를 찾아서 | 1화 전주 편  sJNC99aCHkQ
# 1                             침착맨의 뿌리를 찾아서 | 2화 익산 편  3W0nFEtK2nU
# 2                                        침착맨 삼국지 완전판  hnanNlDbsE4
# 3                                        침착맨 삼국지 동탁전  quwdMWnCE38
# 4                                        침착맨 삼국지 원소전  UXb2DyR_2R4
# ..                                               ...          ...
# 217  배도라지 낚시대회 (with 풍월량, 철면수심, 옥냥이) - 모여봐요 동물의 숲 4화  UaWahLgJSp0
# 218                      나비 아저씨와 농구공 - 모여봐요 동물의 숲 5화  _gJ5ryAmOgk
# 219                   헬등포에서 온 손님(노예) - 모여봐요 동물의 숲 6화  ke4Qdl_YFmo
# 220                                        병건 낚시 4월호  bZWkAW99fjM
# 221                     제1회 시청자 낚시대회 - 모여봐요 동물의 숲 7화  GCsYTN_TJtw
#
# [222 rows x 2 columns]
